# %% [markdown]
# # WINE QUALITY

# %% [markdown]
# In this notebook we will predict the quality of wine using the following steps;
# 1. Data Visualisation
# 2. Data Exploring
# 3. Data modeling

# %%
pip install feature-engine
# Out:
# Requirement already satisfied: feature-engine in c:\users\alvin\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\alvin\anaconda3\lib\site-packages (from feature-engine) (1.1.2)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\alvin\anaconda3\lib\site-packages (from feature-engine) (0.13.2)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\alvin\anaconda3\lib\site-packages (from feature-engine) (1.4.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\alvin\anaconda3\lib\site-packages (from feature-engine) (1.7.3)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\alvin\anaconda3\lib\site-packages (from feature-engine) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\alvin\anaconda3\lib\site-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alvin\anaconda3\lib\site-packages (from pandas>=1.0.3->feature-engine) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\alvin\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->feature-engine) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\alvin\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->feature-engine) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\alvin\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\alvin\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\alvin\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.11.1->feature-engine) (3.0.9)
# Requirement already satisfied: six in c:\users\alvin\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from feature_engine.outliers import Winsorizer
import feature_engine.transformation as vt


from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

from collections import Counter

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
#load the data
df=pd.read_csv('C:\\Users\\ALVIN\\Desktop\\winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# All our features are numerical and we have 1599 observations and 12 feature columns

# %% [markdown]
# # EDA

# %%
df.quality.value_counts(ascending=True)
# Out:
# 3     10
# 8     18
# 4     53
# 7    199
# 6    638
# 5    681
# Name: quality, dtype: int64

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
plt.figure(1,figsize=(10,10))
df.quality.value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='quality'>

# %%
def diagnostic_plots(df,variable,target):
    plt.figure(figsize=(20,4))
     #histogram
    plt.subplot(1,4,1)
    sns.histplot(df[variable],bins=30,color='r')
    plt.title('Histogram')
    
    plt.subplot(1,4,3)
    sns.boxplot(y=df[variable],color='b')
    plt.title('Boxplot')
    
    plt.subplot(1,4,4)
    sns.barplot(x=target, y=variable, data=df)
    plt.title('Barplot')
    
    plt.subplot(1,4,2)
    plt.scatter(df[variable],df[target],color='g')
    plt.title('scatter')
    
    plt.show()

# %%
for variable in df:
    diagnostic_plots(df,variable,'quality')

# %% [markdown]
# The skewness is in every feature and only alcohol does not have outliers

# %%
#check for correlation
corr=df.corr()
plt.figure(figsize=(30,12))
k=12 #no of variables for heatmap
cols=corr.nlargest(k, 'quality')['quality'].index
cm=np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm=sns.heatmap(cm,cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':10}, yticklabels=cols.values, xticklabels=cols.values,cmap='Blues')
plt.show()

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # FEATURE ENGINEERING

# %%
def detect_outliers(df, features):
    outlier_indices=[]
    for c in features:
        Q1=np.percentile(df[c],25)
        Q3=np.percentile(df[c],75)
        IQR= Q3-Q1
        outlier_step=IQR*1.5
        outlier_list_col=df[(df[c]<Q1-outlier_step) |(df[c] > Q3+outlier_step)].index
        outlier_indices.extend(outlier_list_col)
    outlier_indices=Counter(outlier_indices)
    multiple_outliers=list(i for i, v in outlier_indices.items() if v>2)
    
    return multiple_outliers

# %%
diagnostic_plots(df,'fixed acidity','quality')

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.iloc[detect_outliers(df,df.columns[:-1])]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 353            13.5             0.530         0.79             4.8      0.120
# 364            12.8             0.615         0.66             5.8      0.083
# 366            12.8             0.615         0.66             5.8      0.083
# 374            14.0             0.410         0.63             3.8      0.089
# 442            15.6             0.685         0.76             3.7      0.100
# 538            12.9             0.350         0.49             5.8      0.066
# 554            15.5             0.645         0.49             4.2      0.095
# 555            15.5             0.645         0.49             4.2      0.095
# 557            15.6             0.645         0.49             4.2      0.095
# 559            13.0             0.470         0.49             4.3      0.085
# 564            13.0             0.470         0.49             4.3      0.085
# 652            15.9             0.360         0.65             7.5      0.096
# 151             9.2             0.520         1.00             3.4      0.610
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 396             6.6             0.735         0.02             7.9      0.122
# 400             6.6             0.735         0.02             7.9      0.122
# 415             8.6             0.725         0.24             6.6      0.117
# 515             8.5             0.655         0.49             6.1      0.122
# 1114            5.0             0.400         0.50             4.3      0.046
# 1244            5.9             0.290         0.25            13.4      0.067
# 1358            7.4             0.640         0.17             5.4      0.168
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 1474            9.9             0.500         0.50            13.8      0.205
# 1476            9.9             0.500         0.50            13.8      0.205
# 1558            6.9             0.630         0.33             6.7      0.235
# 614             9.2             0.755         0.18             2.2      0.148
# 695             5.1             0.470         0.02             1.3      0.034
# 1319            9.1             0.760         0.68             1.7      0.414
# 588             5.0             0.420         0.24             2.0      0.060
# 821             4.9             0.420         0.00             2.1      0.048
# 1270            5.0             0.380         0.01             1.6      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 353                  23.0                  77.0  1.00180  3.18       0.77
# 364                   7.0                  42.0  1.00220  3.07       0.73
# 366                   7.0                  42.0  1.00220  3.07       0.73
# 374                   6.0                  47.0  1.00140  3.01       0.81
# 442                   6.0                  43.0  1.00320  2.95       0.68
# 538                   5.0                  35.0  1.00140  3.20       0.66
# 554                  10.0                  23.0  1.00315  2.92       0.74
# 555                  10.0                  23.0  1.00315  2.92       0.74
# 557                  10.0                  23.0  1.00315  2.92       0.74
# 559                   6.0                  47.0  1.00210  3.30       0.68
# 564                   6.0                  47.0  1.00210  3.30       0.68
# 652                  22.0                  71.0  0.99760  2.98       0.84
# 151                  32.0                  69.0  0.99960  2.74       2.00
# 14                   52.0                 145.0  0.99860  3.16       0.88
# 15                   51.0                 148.0  0.99860  3.17       0.93
# 396                  68.0                 124.0  0.99940  3.47       0.53
# 400                  68.0                 124.0  0.99940  3.47       0.53
# 415                  31.0                 134.0  1.00140  3.32       1.07
# 515                  34.0                 151.0  1.00100  3.31       1.14
# 1114                 29.0                  80.0  0.99020  3.49       0.66
# 1244                 72.0                 160.0  0.99721  3.33       0.54
# 1358                 52.0                  98.0  0.99736  3.28       0.50
# 1434                 55.0                  95.0  1.00369  3.18       0.77
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 1474                 48.0                  82.0  1.00242  3.16       0.75
# 1476                 48.0                  82.0  1.00242  3.16       0.75
# 1558                 66.0                 115.0  0.99787  3.22       0.56
# 614                  10.0                 103.0  0.99690  2.87       1.36
# 695                  18.0                  44.0  0.99210  3.90       0.62
# 1319                 18.0                  64.0  0.99652  2.90       1.33
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 821                  16.0                  42.0  0.99154  3.71       0.74
# 1270                 26.0                  60.0  0.99084  3.70       0.75
#
#       alcohol  quality
# 353      13.0        5
# 364      10.0        7
# 366      10.0        7
# 374      10.8        6
# 442      11.2        7
# 538      12.0        7
# 554      11.1        5
# 555      11.1        5
# 557      11.1        5
# 559      12.7        6
# 564      12.7        6
# 652      14.9        5
# 151       9.4        4
# 14        9.2        5
# 15        9.2        5
# 396       9.9        5
# 400       9.9        5
# 415       9.3        5
# 515       9.3        5
# 1114     13.6        6
# 1244     10.3        6
# 1358      9.5        5
# 1434      9.0        6
# 1435      9.0        6
# 1474      8.8        5
# 1476      8.8        5
# 1558      9.5        5
# 614      10.2        6
# 695      12.8        6
# 1319      9.1        6
# 588      14.0        8
# 821      14.0        7
# 1270     14.0        6

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
windsoriser = Winsorizer(capping_method='iqr', # choose iqr for IQR rule boundaries or gaussian for mean and std
                          tail='both', # cap left, right or both tails 
                          fold=1.5,
                          variables=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                                     'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                                     'pH', 'sulphates'])

# %%
diagnostic_plots(df,'fixed acidity','quality')

# %%
windsoriser.fit(df)
# Out:
# Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#            variables=['fixed acidity', 'volatile acidity', 'citric acid',
#                       'residual sugar', 'chlorides', 'free sulfur dioxide',
#                       'total sulfur dioxide', 'density', 'pH', 'sulphates'])

# %%
diagnostic_plots(df,'fixed acidity','quality')

# %% [markdown]
# # Normal Distribution

# %% [markdown]
# we shall normalize the variables that showed skewness using log function

# %%
cols=['fixed acidity','volatile acidity','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','sulphates','alcohol']

# %%
lt=vt.LogTransformer(variables=cols)
lt.fit(df)
# Out:
# LogTransformer(variables=['fixed acidity', 'volatile acidity', 'residual sugar',
#                           'chlorides', 'free sulfur dioxide',
#                           'total sulfur dioxide', 'sulphates', 'alcohol'])

# %%
df=lt.transform(df)

# %%
bins=(2,6.5,8)
group_names=['bad','good']
df['quality']=pd.cut(df['quality'],bins=bins, labels=group_names)

# %% [markdown]
# # DATA PREPROCESSING

# %%
encoder=LabelEncoder()

# %%
df['quality']=encoder.fit_transform(df['quality'])
df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       2.001480         -0.356675         0.00        0.641854  -2.577022
# 1       2.054124         -0.127833         0.00        0.955511  -2.322788
# 2       2.054124         -0.274437         0.04        0.832909  -2.385967
# 3       2.415914         -1.272966         0.56        0.641854  -2.590267
# 4       2.001480         -0.356675         0.00        0.641854  -2.577022
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0             2.397895              3.526361   0.9978  3.51  -0.579818
# 1             3.218876              4.204693   0.9968  3.20  -0.385662
# 2             2.708050              3.988984   0.9970  3.26  -0.430783
# 3             2.833213              4.094345   0.9980  3.16  -0.544727
# 4             2.397895              3.526361   0.9978  3.51  -0.579818
#
#     alcohol  quality
# 0  2.240710        0
# 1  2.282382        0
# 2  2.282382        0
# 3  2.282382        0
# 4  2.240710        0

# %% [markdown]
# # scaling

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('quality', axis=1),
                                                    df['quality'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((1119, 11), (480, 11))

# %%
scaler = StandardScaler()


scaler.fit(X_train)


X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Models

# %%
dct = DecisionTreeClassifier(random_state = 42)
svc = SVC(random_state = 42)
rf = RandomForestClassifier(random_state = 42)
logreg = LogisticRegression(random_state = 42)
knn = KNeighborsClassifier()
sgd = SGDClassifier()

# %%
classifiers = [
    ("knn" , knn),
    ("rf" , rf),
    ("logreg" , logreg),
    ("svc", svc),
    ("sgd",sgd),
    ("dct",dct)
]

# %%
for clf_name, clf in classifiers:
   
    clf.fit(X_train, y_train)
    
    
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)

   
    print('{:s} score : {:.3f}'.format(clf_name, acc))
# Out:
# knn score : 0.890
# rf score : 0.921
# logreg score : 0.906
# svc score : 0.912
# sgd score : 0.871
# dct score : 0.892

# %%
param_grid ={
    'n_estimators' : [50,100,200],
    'max_depth': (1,5,10),
    'min_samples_leaf': (1,5,10)
    }

# %%
gridsearch = GridSearchCV(rf, param_grid=param_grid, scoring='accuracy', cv=5,n_jobs=6)

# %%
# %%capture
gridsearch.fit(X_train,y_train)
gridsearch.best_params_

# %%
rf = RandomForestClassifier(max_depth= 10, min_samples_leaf = 1, n_estimators = 100)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10)

# %%
pred = rf.predict(X_test)
print("Accuracy Score:",accuracy_score(pred,y_test))
print("classification Report:\n",classification_report(pred,y_test))
# Out:
# Accuracy Score: 0.9145833333333333
# classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       433
#            1       0.56      0.60      0.58        47
#
#     accuracy                           0.91       480
#    macro avg       0.76      0.77      0.76       480
# weighted avg       0.92      0.91      0.92       480

# %%
cm=confusion_matrix(y_test,pred)
df1=pd.DataFrame(columns=["Bad","Good"], index=["Bad","Good"], data=cm)

f,ax=plt.subplots(figsize=(4,4))
sns.heatmap(df1, annot=True, cmap="Greens",fmt='.0f',ax=ax,linewidths=5,cbar=False)
plt.xlabel("Predicted Label")
plt.xticks(size=12)
plt.yticks(size=12,rotation=0)
plt.ylabel("True Label")
plt.title("Confusion Matrix",size=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
